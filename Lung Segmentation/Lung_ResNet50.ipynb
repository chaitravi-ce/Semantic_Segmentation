# %%
import tensorflow as tf
import numpy as np
import os
import sys
import cv2
import matplotlib.pyplot as plt


from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, UpSampling2D, Concatenate, ZeroPadding2D, Add, AveragePooling2D, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from glob import glob
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.metrics import Recall, Precision
from tensorflow.keras import backend as K
from tensorflow.keras.initializers import glorot_uniform
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Semantic/
# !ls
# Out:
# /content/drive/MyDrive/Semantic
# CXR_png  masks	ResNet50.h5

# %%
mask_path = "./masks/"
train_path = "./CXR_png/"

mask_ids = next(os.walk(mask_path))[2]
masks = [os.path.join(mask_path, f"{name}") for name in mask_ids]
train_ids = [''.join(ids.split('_mask')) for ids in mask_ids]
train = [os.path.join(train_path, f"{name}") for name in train_ids]

# %%
print(len(train))
print(len(masks))
# Out:
# 704
# 704

# %%
train = sorted(train)
masks = sorted(masks)

# %%
x_train, x_test, y_train, y_test = train_test_split(train, masks, test_size=0.2, random_state=42)
print(len(x_train), len(x_test), len(y_train), len(y_test))
# Out:
# 563 141 563 141

# %%
def read_image(x, W=1024, H=1024):
    x = cv2.imread(x, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W,H))
    x = cv2.cvtColor(x, cv2.COLOR_BGR2GRAY)
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

def preprocess(x, y, W=1024, H=1024):
    def f(x,y):
        x = x.decode()
        y = y.decode()
        
        image = read_image(x)
        mask = read_image(y)
        return image, mask
    image, mask = tf.numpy_function(f, [x,y], [tf.float32,tf.float32])
    image.set_shape([H,W,1])
    mask.set_shape([H,W,1])
    return image, mask

# %%
def tf_dataset(x,y,batch_size=1):
    data = tf.data.Dataset.from_tensor_slices((x,y))
    #data = data.shuffle(buffer_size=5000)
    data = data.map(preprocess)
    data = data.batch(batch_size)
    data = data.repeat()
    data = data.prefetch(2)
    return data

# %%
train_dataset = tf_dataset(x_train,y_train)
test_dataset = tf_dataset(x_test, y_test)

# %%
print(train_dataset)
# Out:
# <PrefetchDataset shapes: ((None, 1024, 1024, 1), (None, 1024, 1024, 1)), types: (tf.float32, tf.float32)>

# %%
def read2rgb(x):
    x = cv2.imread(x)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
train_x = train
train_y = masks

fig = plt.figure(figsize=(15,15))

a = fig.add_subplot(1,4,1)
imgplot = plt.imshow(read2rgb(train_x[6]))

a = fig.add_subplot(1,4,2)
imgplot = plt.imshow(read2rgb(train_x[10]))
imgplot.set_clim(0.0,0.7)

a = fig.add_subplot(1,4,3)
imgplot = plt.imshow(read2rgb(train_x[8]))
imgplot.set_clim(0.0,1.4)

a = fig.add_subplot(1,4,4)
imgplot = plt.imshow(read2rgb(train_x[15]))
imgplot.set_clim(0.0,2.1)

fig = plt.figure(figsize=(15,15))

a = fig.add_subplot(1,4,1)
imgplot = plt.imshow(read2rgb(train_y[6]))

a = fig.add_subplot(1,4,2)
imgplot = plt.imshow(read2rgb(train_y[10]))
imgplot.set_clim(0.0,0.7)

a = fig.add_subplot(1,4,3)
imgplot = plt.imshow(read2rgb(train_y[8]))
imgplot.set_clim(0.0,1.4)

a = fig.add_subplot(1,4,4)
imgplot = plt.imshow(read2rgb(train_y[15]))
imgplot.set_clim(0.0,2.1)

# %%
# Block for ResNet

def identity_block(x, f, filters, stage, block):
    
    conv_name = 'res' + str(stage) + block + '_branch'
    bn_name = 'bn' + str(stage) + block + '_branch'
    
    F1, F2, F3 = filters
    
    x_shortcut = x
    
    x = Conv2D(filters=F1, kernel_size=(1,1), strides=(1,1), padding="valid", name=conv_name+'2a', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name+'2a')(x)
    x = Activation("relu")(x)
    
    x = Conv2D(filters=F2, kernel_size=(f,f), strides=(1,1), padding="same", name=conv_name+'2b', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name+'2b')(x)
    x = Activation("relu")(x)
    
    x = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), padding="valid", name=conv_name+'2c', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name+'2c')(x)
    
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
def convolutional_block(x, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    x_shortcut = x

    x = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2b')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '2c')(x)

    x_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(x_shortcut)
    x_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(x_shortcut)

    x = Add()([x, x_shortcut])
    x = Activation('relu')(x)

    return x

# %%
def conv_block(inputs, no):
    
    x = Conv2D(no, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(no, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    return x

# %%
def decoder_block(inputs, skip_features, no):
    
    x = Conv2DTranspose(no, (2,2), strides=(2,2), padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, no)
    
    return x

# %%
def Resnet50(input_shape=(1024, 1024, 1)):
    
    # Input
    X_input = Input(input_shape)
    
    # ResNet50 Model (Encoder)

    X1 = ZeroPadding2D((3, 3))(X_input)

    X1 = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X1)
    X1 = BatchNormalization(axis=3, name='bn_conv1')(X1)
    X1n = Activation('relu')(X1)
    X1 = ZeroPadding2D()(X1n)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X1)

    X2 = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X2 = identity_block(X2, 3, [64, 64, 256], stage=2, block='b')
    X2 = identity_block(X2, 3, [64, 64, 256], stage=2, block='c')

    
    X3 = convolutional_block(X2, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X3 = identity_block(X3, 3, [128, 128, 512], stage=3, block='b')
    X3 = identity_block(X3, 3, [128, 128, 512], stage=3, block='c')
    X3 = identity_block(X3, 3, [128, 128, 512], stage=3, block='d')
    
    X4 = convolutional_block(X3, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X4 = identity_block(X4, 3, [256, 256, 1024], stage=4, block='b')
    X4 = identity_block(X4, 3, [256, 256, 1024], stage=4, block='c')
    X4 = identity_block(X4, 3, [256, 256, 1024], stage=4, block='d')
    X4 = identity_block(X4, 3, [256, 256, 1024], stage=4, block='e')
    X4 = identity_block(X4, 3, [256, 256, 1024], stage=4, block='f')

    X5 = convolutional_block(X4, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X5 = identity_block(X5, 3, [512, 512, 2048], stage=5, block='b')
    X5 = identity_block(X5, 3, [512, 512, 2048], stage=5, block='c')
    

    # X5 = AveragePooling2D(pool_size=(2, 2), padding='same')(X5)
    
    # Skip connections
    
    s1 = X_input
    s2 = X1n
    s3 = X2
    s4 = X3
    
    # Bridge
    
    b = X4
    
    # Decoder
    
    d1 = decoder_block(b, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 3)
    
    out = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    
    
    # print(s1.shape, s2.shape, s3.shape, s4.shape, b.shape, d1.shape, d2.shape, d3.shape, d4.shape)
    
    model = Model(inputs=X_input, outputs=out)

    return model

# %%
net = Resnet50((1024,1024,1))
net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 1030, 1030, 1 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 512, 512, 64) 3200        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 512, 512, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512, 512, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 514, 514, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 64) 0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 256, 256, 64) 4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 256, 256, 64) 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 256, 256, 64) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 256, 256, 64) 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 256, 256, 256 16640       activation_2[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 256, 256, 256 16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 256, 256, 256 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 256, 256, 256 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 256 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 256 0           add[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 256, 256, 64) 16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 256, 256, 64) 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 256, 256, 64) 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 256, 256, 64) 36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 256, 256, 64) 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 256, 256, 64) 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 256, 256, 256 16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 256, 256, 256 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 256 0           bn2b_branch2c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 256 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 256, 256, 64) 16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 256, 256, 64) 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256, 256, 64) 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 256, 256, 64) 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 256, 256, 64) 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 64) 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 256, 256, 256 16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 256, 256, 256 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 256, 256, 256 0           bn2c_branch2c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 256, 256, 256 0           add_2[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 128, 128, 128 32896       activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 128, 128, 128 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 128 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 128, 128, 128 147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 128, 128, 128 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 128 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 128, 128, 512 66048       activation_11[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 128, 128, 512 131584      activation_9[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 128, 128, 512 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 128, 128, 512 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 512 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 512 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 128, 128, 128 65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 128, 128, 128 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 128 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 128, 128, 128 147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 128, 128, 128 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 128 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 128, 128, 512 66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 128, 128, 512 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 512 0           bn3b_branch2c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 512 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 128, 128, 128 65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 128, 128, 128 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 128 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 128, 128, 128 147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 128, 128, 128 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 128 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 128, 128, 512 66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 128, 128, 512 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 512 0           bn3c_branch2c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 512 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 128, 128, 128 65664       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 128, 128, 128 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 128, 128, 128 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 128, 128, 128 147584      activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 128, 128, 128 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 128 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 128, 128, 512 66048       activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 128, 128, 512 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128, 128, 512 0           bn3d_branch2c[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 128, 512 0           add_6[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 64, 64, 256)  131328      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 64, 64, 1024) 525312      activation_21[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 64, 64, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 64, 64, 256)  262400      activation_24[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 64, 64, 256)  262400      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 64, 64, 256)  262400      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 64, 64, 256)  262400      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 64, 64, 256)  262400      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 64, 64, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 64, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 64, 64, 256)  590080      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 64, 64, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 64, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 64, 64, 1024) 263168      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 64, 64, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 64, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 128, 128, 512 2097664     activation_39[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 128, 128, 102 0           conv2d_transpose[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 512 4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 512 2048        conv2d[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 128, 128, 512 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 512 2359808     activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 512 2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 128, 512 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 256, 256 524544      activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 512 0           conv2d_transpose_1[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 256 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 256 1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 256, 256, 256 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 256 590080      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 256 1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 256, 256, 256 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 512, 512, 64) 65600       activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 128 0           conv2d_transpose_2[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512, 512, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 512, 512, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 64) 36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512, 512, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 512, 512, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 1024, 1024, 3 771         activation_54[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1024, 1024, 4 0           conv2d_transpose_3[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1024, 1024, 3 111         concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1024, 1024, 3 12          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 1024, 1024, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1024, 1024, 3 84          activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 1024, 1024, 3 12          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 1024, 1024, 3 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1024, 1024, 1 4           activation_56[0][0]
# ==================================================================================================
# Total params: 20,237,986
# Trainable params: 20,204,054
# Non-trainable params: 33,932
# __________________________________________________________________________________________________

# %%
smooth = 1e-15

def dice_coefficent(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    
    intersection = tf.reduce_sum(y_true*y_pred)
    return (2*intersection + smooth)/ (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def loss(y_true, y_pred):
    return 1 - dice_coefficent(y_true, y_pred)

# %%
lr = 1e-4
opt = tf.keras.optimizers.Adam(lr)
metrics = [dice_coefficent, Recall(), Precision()]

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %%
def create_mask(pred_mask):
  res = pred_mask[-1,:,:]
  res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
  return res

# %%
def show_predictions(dataset=None, num=1):
  if train_dataset:
    for image, mask in train_dataset.take(num):
      pred_mask = net.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([sample_image, sample_mask,
             create_mask(net.predict(sample_image[tf.newaxis, ...]))])

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %%
callbacks = [
    ModelCheckpoint("./ResNet50.h5", verbose=1, save_best_model=True),
    ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
    EarlyStopping(monitor="val_loss", patience=5, verbose=1),
    DisplayCallback()
]

# %%
net.compile(loss=loss,optimizer=opt, metrics=metrics)

# %%
net = tf.keras.models.load_model('./ResNet50.h5', custom_objects={'dice_coefficent':dice_coefficent, 'loss':loss})

# %%
from IPython.display import clear_output

# %%
history += net.fit(train_dataset,steps_per_epoch=500,epochs=10,callbacks=callbacks, validation_data=test_dataset, validation_steps=150)

# %%
history.history
# Out:
# {'dice_coefficent': [0.5136183500289917,
#   0.54645836353302,
#   0.5758652687072754,
#   0.6028808951377869,
#   0.6340163350105286,
#   0.6620371341705322,
#   0.6799294948577881,
#   0.682754397392273,
#   0.6857171058654785,
#   0.687648594379425,
#   0.693539559841156,
#   0.6961452960968018,
#   0.6978186964988708,
#   0.7011799812316895,
#   0.7038962244987488,
#   0.7078549265861511,
#   0.7091375589370728,
#   0.7121773958206177,
#   0.7135605216026306,
#   0.7200324535369873],
#  'loss': [0.4863816201686859,
#   0.45354196429252625,
#   0.4241347014904022,
#   0.39711955189704895,
#   0.3659830093383789,
#   0.3379632830619812,
#   0.3200705647468567,
#   0.317245751619339,
#   0.31428271532058716,
#   0.31235137581825256,
#   0.3064606785774231,
#   0.3038550317287445,
#   0.302181214094162,
#   0.29882025718688965,
#   0.2961038649082184,
#   0.292145311832428,
#   0.2908626198768616,
#   0.2878226041793823,
#   0.2864396274089813,
#   0.2799675762653351],
#  'lr': [1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05,
#   1e-05],
#  'precision': [0.9349634051322937,
#   0.9471956491470337,
#   0.9497580528259277,
#   0.947523832321167,
#   0.9545556902885437,
#   0.9531612992286682,
#   0.9579949378967285,
#   0.9612650871276855,
#   0.9618820548057556,
#   0.9627344608306885,
#   0.9637583494186401,
#   0.9634314179420471,
#   0.965071976184845,
#   0.9648200869560242,
#   0.9655442833900452,
#   0.9657267928123474,
#   0.966177225112915,
#   0.9663456082344055,
#   0.9669811129570007,
#   0.9675280451774597],
#  'recall': [0.9468605518341064,
#   0.957819938659668,
#   0.9589444398880005,
#   0.9587612748146057,
#   0.9637908339500427,
#   0.9612024426460266,
#   0.9641321897506714,
#   0.9663873910903931,
#   0.9672282338142395,
#   0.9677997827529907,
#   0.9682435989379883,
#   0.968951404094696,
#   0.9684669971466064,
#   0.9697349071502686,
#   0.9702041745185852,
#   0.9700987935066223,
#   0.9716318845748901,
#   0.97173011302948,
#   0.9724802374839783,
#   0.9729989767074585],
#  'val_dice_coefficent': [0.4582679867744446,
#   0.5244058966636658,
#   0.574981153011322,
#   0.5432373881340027,
#   0.5650618672370911,
#   0.5376670360565186,
#   0.6734809875488281,
#   0.6784501671791077,
#   0.6820614337921143,
#   0.6845205426216125,
#   0.686310887336731,
#   0.6893928050994873,
#   0.6889463067054749,
#   0.6956921815872192,
#   0.6972125768661499,
#   0.6973816156387329,
#   0.6987388134002686,
#   0.7032550573348999,
#   0.7057117223739624,
#   0.7065272927284241],
#  'val_loss': [0.5417318940162659,
#   0.4755942225456238,
#   0.42501893639564514,
#   0.45676255226135254,
#   0.4349380433559418,
#   0.4623330235481262,
#   0.32651910185813904,
#   0.3215499222278595,
#   0.3179386556148529,
#   0.3154793381690979,
#   0.31368905305862427,
#   0.3106072247028351,
#   0.31105366349220276,
#   0.3043076694011688,
#   0.3027874529361725,
#   0.3026183545589447,
#   0.3012610375881195,
#   0.2967449426651001,
#   0.29428836703300476,
#   0.2934727966785431],
#  'val_precision': [0.4170100688934326,
#   0.6832443475723267,
#   0.874221682548523,
#   0.5726460814476013,
#   0.6221940517425537,
#   0.9448177814483643,
#   0.962024450302124,
#   0.962081253528595,
#   0.9605469703674316,
#   0.9604329466819763,
#   0.9601218700408936,
#   0.9523943662643433,
#   0.9420673251152039,
#   0.9589037895202637,
#   0.9614776372909546,
#   0.9526976943016052,
#   0.9444136023521423,
#   0.9661285877227783,
#   0.9531344175338745,
#   0.9564118385314941],
#  'val_recall': [0.9666333198547363,
#   0.9325458407402039,
#   0.9659556746482849,
#   0.9839109182357788,
#   0.9758278727531433,
#   0.5862698554992676,
#   0.9488606452941895,
#   0.9500856995582581,
#   0.9521562457084656,
#   0.9566861987113953,
#   0.9516769051551819,
#   0.9612926244735718,
#   0.9646457433700562,
#   0.9545968174934387,
#   0.9498340487480164,
#   0.9544088840484619,
#   0.9559152722358704,
#   0.9376463294029236,
#   0.9514073729515076,
#   0.943574070930481]}

# %%
plt.plot(history.history['dice_coefficent'])
plt.plot(history.history['val_dice_coefficent'])
plt.title('dice_coefficent')
plt.ylabel('dice_coefficent')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Precision and Recall')
plt.ylabel('Params')
plt.xlabel('epoch')
plt.legend(['precision', 'val_precision', 'recall', 'val_recall'], loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))

a = fig.add_subplot(1,7,1)
imgplot = plt.imshow(read2rgb(train_x[6]))

a = fig.add_subplot(1,7,2)
imgplot = plt.imshow(read2rgb(train_x[10]))
imgplot.set_clim(0.0,0.7)

a = fig.add_subplot(1,7,3)
imgplot = plt.imshow(read2rgb(train_x[8]))
imgplot.set_clim(0.0,1.4)

a = fig.add_subplot(1,7,4)
imgplot = plt.imshow(read2rgb(train_x[15]))
imgplot.set_clim(0.0,2.1)

a = fig.add_subplot(1,7,5)
imgplot = plt.imshow(read2rgb(train_x[2]))

a = fig.add_subplot(1,7,6)
imgplot = plt.imshow(read2rgb(train_x[4]))

a = fig.add_subplot(1,7,7)
imgplot = plt.imshow(read2rgb(train_x[7]))

fig = plt.figure(figsize=(15,15))

a = fig.add_subplot(1,7,1)
imgplot = plt.imshow(read2rgb(train_y[6]))

a = fig.add_subplot(1,7,2)
imgplot = plt.imshow(read2rgb(train_y[10]))
imgplot.set_clim(0.0,0.7)

a = fig.add_subplot(1,7,3)
imgplot = plt.imshow(read2rgb(train_y[8]))
imgplot.set_clim(0.0,1.4)

a = fig.add_subplot(1,7,4)
imgplot = plt.imshow(read2rgb(train_y[15]))
imgplot.set_clim(0.0,1.4)

a = fig.add_subplot(1,7,5)
imgplot = plt.imshow(read2rgb(train_y[2]))
imgplot.set_clim(0.0,2.1)

a = fig.add_subplot(1,7,6)
imgplot = plt.imshow(read2rgb(train_y[4]))
imgplot.set_clim(0.0,2.1)

a = fig.add_subplot(1,7,7)
imgplot = plt.imshow(read2rgb(train_y[7]))
imgplot.set_clim(0.0,2.1)

fig = plt.figure(figsize=(15,15))

img = read_image(train_x[6])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,1)
imgplot = plt.imshow(res)

img = read_image(train_x[10])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,2)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,0.7)

img = read_image(train_x[8])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,3)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,1.4)


img = read_image(train_x[15])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,4)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,2.1)

img = read_image(train_x[2])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,5)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,2.1)

img = read_image(train_x[4])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,6)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,2.1)

img = read_image(train_x[7])
img = np.expand_dims(img, axis=0)
res = net.predict(img)
res = res[-1,:,:]
res = cv2.cvtColor(res, cv2.COLOR_BGR2RGB)
a = fig.add_subplot(1,7,7)
imgplot = plt.imshow(res)
imgplot.set_clim(0.0,2.1)
